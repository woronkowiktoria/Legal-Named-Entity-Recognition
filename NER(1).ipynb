# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NLP_project/
# Out:
# /content/drive/MyDrive/NLP_project

# %%
# !pip install --upgrade gensim
# !pip install pytorch-crf
# !pip install nervaluate
# !pip install accelerate -U
# !pip install sklearn_crfsuite
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Data Augmentation extension**
#
# All the modifications for this extension has been made in utils/dataset.py

# %%
# !python main.py \
    --ds_train_path data/NER_TRAIN_JUDGEMENT_train.json \
    --ds_valid_path data/NER_TRAIN_JUDGEMENT_validation.json \
    --ds_test_path data/NER_DEV_JUDGEMENT.json \
    --output_folder results/ \
    --batch 1 \
    --num_epochs 5 \
    --lr 1e-4 \
    --weight_decay 0.01 \
    --warmup_ratio 0.06

# %% [markdown]
# For the evaluation of CRF model, a ner_eval file is used from repository: https://github.com/davidsbatista/NER-Evaluation

# %% [markdown]
# **CRF extension**

# %%
# !git clone https://github.com/davidsbatista/NER-Evaluation

# %%
# !python main_crf.py
# Out:
#                 precision    recall  f1-score   support
#
#  B-CASE_NUMBER       0.82      0.68      0.74       121
#  I-CASE_NUMBER       0.82      0.85      0.84       442
#        B-COURT       0.93      0.84      0.88       178
#        I-COURT       0.87      0.75      0.80       367
#         B-DATE       0.95      0.90      0.93       218
#         I-DATE       0.94      0.93      0.93       203
#          B-GPE       0.68      0.54      0.61       182
#          I-GPE       0.43      0.25      0.32        48
#        B-JUDGE       0.83      0.62      0.71         8
#        I-JUDGE       1.00      0.86      0.92         7
#          B-ORG       0.62      0.51      0.56       157
#          I-ORG       0.53      0.58      0.55       346
# B-OTHER_PERSON       0.75      0.67      0.71       275
# I-OTHER_PERSON       0.74      0.68      0.71       200
#   B-PETITIONER       0.25      0.22      0.24         9
#   I-PETITIONER       0.20      0.17      0.18        12
# ...
